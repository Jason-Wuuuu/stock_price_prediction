# %% [markdown]
# # Long-term Stock Price Forecasting with LSTM

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import datetime
import pytz

import yfinance as yf

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.regularizers import l1_l2
from keras.callbacks import EarlyStopping
# Out:
# 2024-02-26 03:13:58.857100: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Check the allocated GPU
# !nvidia-smi

# %%
import tensorflow as tf

# Check if TensorFlow is able to detect the GPU
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Please install GPU version of TF

# %% [markdown]
# ## Data Collection

# %%
# Fetch stock data and earnings dates
def fetch_stock_data_with_earnings(ticker, period):
    try:
        stock = yf.Ticker(ticker)

        data = stock.history(period=period)
        data.index = data.index.date

        earnings = stock.earnings_dates
        earnings.index = earnings.index.date

        return data, earnings
    except Exception as e:
        print(f"Error fetching data for {ticker}: {e}")
        return None, None

# %%
# Fetch stock data
ticker = "TSLA"
period = "2y"

data, earnings = fetch_stock_data_with_earnings(ticker, period)
if data is None:
    raise ValueError("Failed to fetch stock data.")

# %% [markdown]
# ## Merge S&P 500 Data

# %%
# Fetch S&P 500 historical data
sp500 = yf.Ticker("^GSPC")
sp500_data = sp500.history(period=period)
sp500_data.index = sp500_data.index.date

data_sp500 = sp500_data[['Close']]
data_sp500.columns = ['SP500_Close']    # Rename the columns for clarity
data = data.merge(data_sp500, how='left', left_index=True, right_index=True)

data = data.drop(columns=['Dividends', 'Stock Splits']) # Drop unused columns

# %%
data.tail()
# Out:
#                   Open        High         Low       Close     Volume  \
# 2024-02-16  202.059998  203.169998  197.399994  199.949997  111173600
# 2024-02-20  196.130005  198.600006  189.130005  193.759995  104545800
# 2024-02-21  193.360001  199.440002  191.949997  194.770004  103844000
# 2024-02-22  194.000000  198.320007  191.360001  197.410004   92739500
# 2024-02-23  195.309998  197.570007  191.500000  191.970001   78670300
#
#             SP500_Close
# 2024-02-16  5005.569824
# 2024-02-20  4975.509766
# 2024-02-21  4981.799805
# 2024-02-22  5087.029785
# 2024-02-23  5088.799805

# %%
plt.figure(figsize=(14, 7))  # Set figure size

# Plot ticker 'Close' price with the first y-axis
ax1 = plt.gca()
line1 = ax1.plot(data.index, data['Close'], label='Ticker Close Price', color='blue')
ax1.set_ylabel('Ticker Close Price', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Plot 'SP500_Close' with the second y-axis
ax2 = ax1.twinx()
line2 = ax2.plot(data.index, data['SP500_Close'], label='S&P 500 Close Price', color='red', linestyle='--')
ax2.set_ylabel('S&P 500 Close Price', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title('Ticker Close Price vs. S&P 500 Close Price')
plt.xlabel('Date')

# Combine legends
lines = line1 + line2
labels = [l.get_label() for l in lines]
plt.legend(lines, labels)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Function to check if the current time is within trading hours
def is_trading_hours():
    eastern = pytz.timezone('US/Eastern')
    now_eastern = datetime.datetime.now(eastern)

    # Define market open and close times (9:30 AM to 4:00 PM)
    market_open = now_eastern.replace(hour=9, minute=30, second=0, microsecond=0)
    market_close = now_eastern.replace(hour=16, minute=0, second=0, microsecond=0)

    return market_open <= now_eastern <= market_close

# Drop the last row if it's within trading hours (incomplete data)
if is_trading_hours():
    print('Trading Hours.')
    data = data.drop(data.tail(1).index)
else:
    print('After Hours.')
# Out:
# After Hours.

# %% [markdown]
# ## Feature Engineering

# %%
# EMA
short_span, long_span = 10, 50

data['EMA_Short'] = data['Close'].ewm(span=short_span, adjust=False).mean()
data['EMA_Long'] = data['Close'].ewm(span=long_span, adjust=False).mean()

# RSI
delta = data['Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
rs = gain / loss
data['RSI'] = 100 - (100 / (1 + rs))

# MACD
exp1 = data['Close'].ewm(span=12, adjust=False).mean()
exp2 = data['Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = exp1 - exp2

# %% [markdown]
# ### EMA (Exponential Moving Average)
#
# - EMA is a type of moving average that places a greater weight and significance on the most recent data points. It is more responsive to new information compared to the SMA.
# - Usage in analysis: EMA is often used to identify the direction of the trend, with prices above the EMA suggesting an uptrend and prices below indicating a downtrend. Traders might use short-term EMAs to make quick, momentum-based decisions and longer-term EMAs for overall trend direction.

# %%
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Close Price')
plt.plot(data.index, data['EMA_Short'], label='EMA Short')
plt.plot(data.index, data['EMA_Long'], label='EMA Long')
plt.title('EMA Short vs EMA Long')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ### RSI (Relative Strength Index)
#
# - RSI is a momentum oscillator that measures the speed and change of price movements on a scale of 0 to 100. It is used to identify overbought or oversold conditions in a security's price.
# - Usage in analysis: Values above 70 are considered overbought (suggesting a potential sell signal), while values below 30 are considered oversold (indicating a potential buy signal). RSI can also show divergence signals, where the price trend and RSI trend move in opposite directions, suggesting a potential reversal.

# %%
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['RSI'], label='RSI')
plt.title('Relative Strength Index (RSI) Over Time')
plt.xlabel('Date')
plt.axhline(70, linestyle='--', color='red')  # Overbought line
plt.axhline(30, linestyle='--', color='green')  # Oversold line
plt.ylabel('RSI')
plt.legend()
plt.show()

# %% [markdown]
# ### MACD (Moving Average Convergence Divergence)
#
# - MACD is a trend-following momentum indicator that shows the relationship between two moving averages of a security's price. It consists of the MACD line (difference between two EMAs), a signal line (EMA of the MACD line), and a histogram (difference between MACD and its signal line).
# - Usage in analysis: MACD is used to identify changes in the strength, direction, momentum, and duration of a trend. A bullish crossover occurs when the MACD crosses above its signal line, suggesting a buy signal, while a bearish crossover (MACD falls below the signal line) suggests a sell signal. The divergence between the MACD and price action can also indicate potential market reversals.

# %%
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['MACD'], label='MACD')
plt.title('Moving Average Convergence Divergence (MACD)')
plt.xlabel('Date')
plt.ylabel('MACD Value')
plt.legend()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 502 entries, 2022-02-24 to 2024-02-23
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         502 non-null    float64
#  1   High         502 non-null    float64
#  2   Low          502 non-null    float64
#  3   Close        502 non-null    float64
#  4   Volume       502 non-null    int64
#  5   SP500_Close  502 non-null    float64
#  6   EMA_Short    502 non-null    float64
#  7   EMA_Long     502 non-null    float64
#  8   RSI          489 non-null    float64
#  9   MACD         502 non-null    float64
# dtypes: float64(9), int64(1)
# memory usage: 59.3+ KB

# %%
earnings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 2025-01-22 to 2022-04-20
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   EPS Estimate  9 non-null      float64
#  1   Reported EPS  8 non-null      float64
#  2   Surprise(%)   8 non-null      float64
# dtypes: float64(3)
# memory usage: 384.0+ bytes

# %% [markdown]
# ## Data Preprocessing

# %%
# Splitting data into features and labels
features = data.drop(columns=['Close'])
target = data[['Close']]

# %%
# Scaling
feature_scaler = MinMaxScaler(feature_range=(0, 1))
features= features.bfill()
scaled_features = feature_scaler.fit_transform(features)

target_scaler = MinMaxScaler(feature_range=(0, 1))
scaled_target = target_scaler.fit_transform(target)


# Convert scaled data back to DataFrame for further processing
scaled_features_df = pd.DataFrame(scaled_features, index=data.index, columns=features.columns)
scaled_target_df = pd.DataFrame(scaled_target, index=data.index, columns=target.columns)

# %% [markdown]
# ## Merge earnings data

# %%
# Merge earnings data
scaled_features_df = scaled_features_df.merge(earnings, how='left', left_index=True, right_index=True)
scaled_features_df = scaled_features_df.fillna(method='ffill').fillna(method='bfill')

# Display the merged dataframe
scaled_features_df
# Out:
# /var/folders/hd/pv9sg75d6b38kvxtq9c67bw40000gn/T/ipykernel_93615/2796264541.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   scaled_features_df = scaled_features_df.fillna(method='ffill').fillna(method='bfill')
#                 Open      High       Low    Volume  SP500_Close  EMA_Short  \
# 2022-02-24  0.473093  0.571451  0.504649  0.353035     0.470753   0.629748
# 2022-02-25  0.604654  0.592268  0.610037  0.129202     0.534221   0.632105
# 2022-02-28  0.611640  0.662423  0.651362  0.215854     0.527137   0.649724
# 2022-03-01  0.677723  0.678347  0.701331  0.124288     0.482368   0.662570
# 2022-03-02  0.680684  0.674189  0.689168  0.123821     0.535472   0.677101
# ...              ...       ...       ...       ...          ...        ...
# 2024-02-16  0.359217  0.335437  0.366775  0.261814     0.944945   0.312882
# 2024-02-20  0.337713  0.318669  0.335043  0.236777     0.925061   0.313629
# 2024-02-21  0.327668  0.321751  0.345863  0.234126     0.929222   0.315024
# 2024-02-22  0.329989  0.317641  0.343599  0.192179     0.998829   0.318218
# 2024-02-23  0.334740  0.314890  0.344137  0.139033     1.000000   0.316603
#
#             EMA_Long       RSI      MACD  EPS Estimate  Reported EPS  \
# 2022-02-24  0.696217  0.477219  0.494938          0.75          1.07
# 2022-02-25  0.696944  0.477219  0.499728          0.75          1.07
# 2022-02-28  0.702487  0.477219  0.535310          0.75          1.07
# 2022-03-01  0.707327  0.477219  0.559536          0.75          1.07
# 2022-03-02  0.713219  0.477219  0.585952          0.75          1.07
# ...              ...       ...       ...           ...           ...
# 2024-02-16  0.357811  0.568797  0.350982          0.74          0.71
# 2024-02-20  0.353528  0.495796  0.362748          0.74          0.71
# 2024-02-21  0.349656  0.549739  0.375067          0.74          0.71
# 2024-02-22  0.346569  0.558761  0.390255          0.74          0.71
# 2024-02-23  0.342297  0.512103  0.394756          0.74          0.71
#
#             Surprise(%)
# 2022-02-24       0.4256
# 2022-02-25       0.4256
# 2022-02-28       0.4256
# 2022-03-01       0.4256
# 2022-03-02       0.4256
# ...                 ...
# 2024-02-16      -0.0439
# 2024-02-20      -0.0439
# 2024-02-21      -0.0439
# 2024-02-22      -0.0439
# 2024-02-23      -0.0439
#
# [502 rows x 12 columns]

# %%
scaled_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 502 entries, 2022-02-24 to 2024-02-23
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          502 non-null    float64
#  1   High          502 non-null    float64
#  2   Low           502 non-null    float64
#  3   Volume        502 non-null    float64
#  4   SP500_Close   502 non-null    float64
#  5   EMA_Short     502 non-null    float64
#  6   EMA_Long      502 non-null    float64
#  7   RSI           502 non-null    float64
#  8   MACD          502 non-null    float64
#  9   EPS Estimate  502 non-null    float64
#  10  Reported EPS  502 non-null    float64
#  11  Surprise(%)   502 non-null    float64
# dtypes: float64(12)
# memory usage: 67.1+ KB

# %% [markdown]
# ## Training

# %%
def create_sequences(features, target, sequence_length, n_days):
    X, y = [], []
    for i in range(len(features) - sequence_length - n_days + 1):
        X.append(features.iloc[i:(i + sequence_length)].values)
        y.append(target.iloc[(i + sequence_length):(i + sequence_length + n_days)].values)
    return np.array(X), np.array(y).reshape(-1, n_days)

sequence_length = 60  # Number of days in each sequence
n_days = 5  # Number of days to predict

X, y = create_sequences(scaled_features_df, scaled_target_df, sequence_length, n_days)

# %%
# Model parameters

num_layers = 1
size_layer = 64
epochs = 30
dropout_rate = 0.2
dense_nums = 64
reg_rate = 0.0001
batch_size = 5

# %%
test_size = 150 # Number of samples to be used for testing

# Split data into training and test sets
X_train, X_test = X[:-test_size], X[-test_size:]
y_train, y_test = y[:-test_size], y[-test_size:]

print('training', len(X_train), len(X_test))
print('testing', len(y_train), len(y_test))
# Out:
# training 288 150
# testing 288 150

# %%
# TimeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=10)

# LSTM model with l1_l2 Regularization and Dropout
def build_model(input_shape, num_layers=2, size_layer=128, dropout_rate=0.2, dense_nums=64, n_days=5, reg_rate=0.01):
    model = Sequential()
    reg = l1_l2(l1=reg_rate, l2=reg_rate)

    for i in range(num_layers):

        if i == 0:  # If it's the first layer, specify the input shape
            model.add(LSTM(size_layer, return_sequences=(num_layers > 1), kernel_regularizer=reg, input_shape=input_shape))
        else:  # Subsequent layers will automatically infer the input shape
            model.add(LSTM(size_layer, return_sequences=(i != num_layers - 1), kernel_regularizer=reg))

        # Add dropout after each LSTM layer
        model.add(Dropout(dropout_rate))

        # Optionally, add a Dense layer with ReLU activation after each LSTM layer (except the last one)
        if i < num_layers - 1:
            model.add(Dense(dense_nums, activation='relu'))

    model.add(Dense(n_days, activation='linear'))
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])

    return model

# Setup early stopping to avoid overfitting
early_stopping = EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True)

# %%
best_val_loss = np.inf
best_model = None
best_history = None


# Cross-validate using TimeSeriesSplit
for train_index, val_index in tscv.split(X_train):
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    # Create and fit the LSTM model
    model = build_model(input_shape=(sequence_length, scaled_features_df.shape[1]), # (sequence_length, number_of_features)
                        num_layers=num_layers,
                        size_layer=size_layer,
                        dropout_rate=dropout_rate,
                        dense_nums=dense_nums,
                        reg_rate=reg_rate,
                        n_days=n_days
                        )

    # Fit the model with Early Stopping
    history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(
        X_val_fold, y_val_fold), callbacks=[early_stopping], verbose=1)

    # Track the best model based on validation loss
    val_loss = np.min(history.history['val_loss'])
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model
        best_history = history
# Out:
# Epoch 1/30
# 58/58 [==============================] - 5s 34ms/step - loss: 0.0635 - mae: 0.1487 - val_loss: 0.0364 - val_mae: 0.0970
# Epoch 2/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0346 - mae: 0.0921 - val_loss: 0.0256 - val_mae: 0.0635
# Epoch 3/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0283 - mae: 0.0832 - val_loss: 0.0221 - val_mae: 0.0609
# Epoch 4/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0242 - mae: 0.0769 - val_loss: 0.0184 - val_mae: 0.0559
# Epoch 5/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0209 - mae: 0.0726 - val_loss: 0.0155 - val_mae: 0.0514
# Epoch 6/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0174 - mae: 0.0664 - val_loss: 0.0160 - val_mae: 0.0623
# Epoch 7/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0160 - mae: 0.0657 - val_loss: 0.0125 - val_mae: 0.0502
# Epoch 8/30
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0143 - mae: 0.0634 - val_loss: 0.0137 - val_mae: 0.0604
# Epoch 9/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0135 - mae: 0.0631 - val_loss: 0.0129 - val_mae: 0.0613
# Epoch 10/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0128 - mae: 0.0627 - val_loss: 0.0091 - val_mae: 0.0464
# Epoch 11/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0117 - mae: 0.0598 - val_loss: 0.0108 - val_mae: 0.0558
# Epoch 12/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0106 - mae: 0.0572 - val_loss: 0.0084 - val_mae: 0.0465
# Epoch 13/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0109 - mae: 0.0601 - val_loss: 0.0081 - val_mae: 0.0475
# Epoch 14/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0101 - mae: 0.0577 - val_loss: 0.0093 - val_mae: 0.0539
# Epoch 15/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0102 - mae: 0.0593 - val_loss: 0.0075 - val_mae: 0.0466
# Epoch 16/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0095 - mae: 0.0566 - val_loss: 0.0102 - val_mae: 0.0633
# Epoch 17/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0090 - mae: 0.0555 - val_loss: 0.0067 - val_mae: 0.0459
# Epoch 18/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0088 - mae: 0.0573 - val_loss: 0.0063 - val_mae: 0.0461
# Epoch 19/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0084 - mae: 0.0553 - val_loss: 0.0069 - val_mae: 0.0468
# Epoch 20/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0078 - mae: 0.0531 - val_loss: 0.0082 - val_mae: 0.0546
# Epoch 21/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0077 - mae: 0.0521 - val_loss: 0.0064 - val_mae: 0.0461
# Epoch 22/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0077 - mae: 0.0537 - val_loss: 0.0059 - val_mae: 0.0451
# Epoch 23/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0070 - mae: 0.0509 - val_loss: 0.0057 - val_mae: 0.0464
# Epoch 24/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0078 - mae: 0.0557 - val_loss: 0.0132 - val_mae: 0.0885
# Epoch 25/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0068 - mae: 0.0499 - val_loss: 0.0078 - val_mae: 0.0565
# Epoch 26/30
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0064 - mae: 0.0493 - val_loss: 0.0060 - val_mae: 0.0472
# Epoch 27/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0067 - mae: 0.0509 - val_loss: 0.0069 - val_mae: 0.0520
# Epoch 28/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0069 - mae: 0.0528 - val_loss: 0.0063 - val_mae: 0.0485
# Epoch 29/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0064 - mae: 0.0500 - val_loss: 0.0059 - val_mae: 0.0468
# Epoch 30/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0061 - mae: 0.0496 - val_loss: 0.0068 - val_mae: 0.0524
# Epoch 1/30
# 58/58 [==============================] - 3s 18ms/step - loss: 0.0579 - mae: 0.1398 - val_loss: 0.0291 - val_mae: 0.0649
# Epoch 2/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0339 - mae: 0.0900 - val_loss: 0.0237 - val_mae: 0.0561
# Epoch 3/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0275 - mae: 0.0784 - val_loss: 0.0251 - val_mae: 0.0711
# Epoch 4/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0231 - mae: 0.0726 - val_loss: 0.0176 - val_mae: 0.0537
# Epoch 5/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0196 - mae: 0.0672 - val_loss: 0.0162 - val_mae: 0.0602
# Epoch 6/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0169 - mae: 0.0637 - val_loss: 0.0157 - val_mae: 0.0584
# Epoch 7/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0157 - mae: 0.0635 - val_loss: 0.0129 - val_mae: 0.0573
# Epoch 8/30
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0143 - mae: 0.0624 - val_loss: 0.0116 - val_mae: 0.0519
# Epoch 9/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0129 - mae: 0.0592 - val_loss: 0.0107 - val_mae: 0.0517
# Epoch 10/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0125 - mae: 0.0617 - val_loss: 0.0105 - val_mae: 0.0527
# Epoch 11/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0109 - mae: 0.0560 - val_loss: 0.0098 - val_mae: 0.0512
# Epoch 12/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0109 - mae: 0.0570 - val_loss: 0.0100 - val_mae: 0.0523
# Epoch 13/30
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0099 - mae: 0.0554 - val_loss: 0.0086 - val_mae: 0.0512
# Epoch 14/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0099 - mae: 0.0566 - val_loss: 0.0111 - val_mae: 0.0625
# Epoch 15/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0096 - mae: 0.0552 - val_loss: 0.0081 - val_mae: 0.0522
# Epoch 16/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0094 - mae: 0.0562 - val_loss: 0.0103 - val_mae: 0.0585
# Epoch 17/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0087 - mae: 0.0532 - val_loss: 0.0080 - val_mae: 0.0494
# Epoch 18/30
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0080 - mae: 0.0500 - val_loss: 0.0082 - val_mae: 0.0512
# Epoch 19/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0085 - mae: 0.0539 - val_loss: 0.0097 - val_mae: 0.0593
# Epoch 20/30
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0077 - mae: 0.0514 - val_loss: 0.0087 - val_mae: 0.0542
# Epoch 21/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0076 - mae: 0.0495 - val_loss: 0.0068 - val_mae: 0.0496
# Epoch 22/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0080 - mae: 0.0524 - val_loss: 0.0086 - val_mae: 0.0560
# Epoch 23/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0076 - mae: 0.0516 - val_loss: 0.0069 - val_mae: 0.0498
# Epoch 24/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0071 - mae: 0.0498 - val_loss: 0.0071 - val_mae: 0.0498
# Epoch 25/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0071 - mae: 0.0507 - val_loss: 0.0080 - val_mae: 0.0539
# Epoch 26/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.0072 - mae: 0.0514 - val_loss: 0.0075 - val_mae: 0.0527
# Epoch 27/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0068 - mae: 0.0502 - val_loss: 0.0064 - val_mae: 0.0479
# Epoch 28/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0065 - mae: 0.0482 - val_loss: 0.0069 - val_mae: 0.0505
# Epoch 29/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0061 - mae: 0.0468 - val_loss: 0.0061 - val_mae: 0.0521
# Epoch 30/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0065 - mae: 0.0504 - val_loss: 0.0088 - val_mae: 0.0619
# Epoch 1/30
# 58/58 [==============================] - 6s 39ms/step - loss: 0.0583 - mae: 0.1380 - val_loss: 0.0298 - val_mae: 0.0656
# Epoch 2/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.0336 - mae: 0.0875 - val_loss: 0.0247 - val_mae: 0.0576
# Epoch 3/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.0283 - mae: 0.0793 - val_loss: 0.0208 - val_mae: 0.0555
# Epoch 4/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.0235 - mae: 0.0720 - val_loss: 0.0206 - val_mae: 0.0669
# Epoch 5/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.0214 - mae: 0.0727 - val_loss: 0.0161 - val_mae: 0.0522
# Epoch 6/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.0183 - mae: 0.0679 - val_loss: 0.0156 - val_mae: 0.0617
# Epoch 7/30
# 58/58 [==============================] - 2s 38ms/step - loss: 0.0165 - mae: 0.0664 - val_loss: 0.0125 - val_mae: 0.0516
# Epoch 8/30
# 58/58 [==============================] - 2s 33ms/step - loss: 0.0148 - mae: 0.0627 - val_loss: 0.0122 - val_mae: 0.0547
# Epoch 9/30
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0135 - mae: 0.0609 - val_loss: 0.0109 - val_mae: 0.0500
# Epoch 10/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.0130 - mae: 0.0617 - val_loss: 0.0127 - val_mae: 0.0665
# Epoch 11/30
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0122 - mae: 0.0614 - val_loss: 0.0096 - val_mae: 0.0510
# Epoch 12/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0110 - mae: 0.0577 - val_loss: 0.0096 - val_mae: 0.0543
# Epoch 13/30
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0105 - mae: 0.0568 - val_loss: 0.0081 - val_mae: 0.0455
# Epoch 14/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0103 - mae: 0.0567 - val_loss: 0.0077 - val_mae: 0.0455
# Epoch 15/30
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0096 - mae: 0.0547 - val_loss: 0.0088 - val_mae: 0.0551
# Epoch 16/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.0096 - mae: 0.0557 - val_loss: 0.0114 - val_mae: 0.0720
# Epoch 17/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0091 - mae: 0.0553 - val_loss: 0.0068 - val_mae: 0.0431
# Epoch 18/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0080 - mae: 0.0493 - val_loss: 0.0074 - val_mae: 0.0494
# Epoch 19/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0081 - mae: 0.0519 - val_loss: 0.0070 - val_mae: 0.0481
# Epoch 20/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0081 - mae: 0.0528 - val_loss: 0.0062 - val_mae: 0.0410
# Epoch 21/30
# 58/58 [==============================] - 2s 26ms/step - loss: 0.0084 - mae: 0.0540 - val_loss: 0.0069 - val_mae: 0.0498
# Epoch 22/30
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0074 - mae: 0.0501 - val_loss: 0.0061 - val_mae: 0.0448
# Epoch 23/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0068 - mae: 0.0486 - val_loss: 0.0064 - val_mae: 0.0484
# Epoch 24/30
# 58/58 [==============================] - 1s 26ms/step - loss: 0.0073 - mae: 0.0509 - val_loss: 0.0054 - val_mae: 0.0401
# Epoch 25/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0068 - mae: 0.0488 - val_loss: 0.0069 - val_mae: 0.0528
# Epoch 26/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0068 - mae: 0.0501 - val_loss: 0.0060 - val_mae: 0.0469
# Epoch 27/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0065 - mae: 0.0491 - val_loss: 0.0060 - val_mae: 0.0487
# Epoch 28/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0066 - mae: 0.0490 - val_loss: 0.0060 - val_mae: 0.0480
# Epoch 29/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0064 - mae: 0.0494 - val_loss: 0.0089 - val_mae: 0.0696
# Epoch 30/30
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0064 - mae: 0.0491 - val_loss: 0.0052 - val_mae: 0.0443
# Epoch 1/30
# 58/58 [==============================] - 5s 35ms/step - loss: 0.0588 - mae: 0.1408 - val_loss: 0.0265 - val_mae: 0.0536
# Epoch 2/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0322 - mae: 0.0862 - val_loss: 0.0245 - val_mae: 0.0576
# Epoch 3/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0270 - mae: 0.0765 - val_loss: 0.0198 - val_mae: 0.0507
# Epoch 4/30
# 58/58 [==============================] - 2s 28ms/step - loss: 0.0229 - mae: 0.0722 - val_loss: 0.0166 - val_mae: 0.0470
# Epoch 5/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0194 - mae: 0.0659 - val_loss: 0.0145 - val_mae: 0.0470
# Epoch 6/30
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0174 - mae: 0.0665 - val_loss: 0.0126 - val_mae: 0.0445
# Epoch 7/30
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0157 - mae: 0.0649 - val_loss: 0.0122 - val_mae: 0.0513
# Epoch 8/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0141 - mae: 0.0620 - val_loss: 0.0105 - val_mae: 0.0449
# Epoch 9/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0133 - mae: 0.0612 - val_loss: 0.0094 - val_mae: 0.0423
# Epoch 10/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0127 - mae: 0.0622 - val_loss: 0.0091 - val_mae: 0.0438
# Epoch 11/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0111 - mae: 0.0571 - val_loss: 0.0086 - val_mae: 0.0428
# Epoch 12/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0110 - mae: 0.0585 - val_loss: 0.0079 - val_mae: 0.0419
# Epoch 13/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0104 - mae: 0.0568 - val_loss: 0.0086 - val_mae: 0.0501
# Epoch 14/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0100 - mae: 0.0558 - val_loss: 0.0089 - val_mae: 0.0547
# Epoch 15/30
# 58/58 [==============================] - 2s 26ms/step - loss: 0.0093 - mae: 0.0540 - val_loss: 0.0079 - val_mae: 0.0491
# Epoch 16/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.0094 - mae: 0.0562 - val_loss: 0.0074 - val_mae: 0.0476
# Epoch 17/30
# 58/58 [==============================] - 2s 30ms/step - loss: 0.0083 - mae: 0.0509 - val_loss: 0.0069 - val_mae: 0.0446
# Epoch 18/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0082 - mae: 0.0522 - val_loss: 0.0081 - val_mae: 0.0545
# Epoch 19/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0089 - mae: 0.0553 - val_loss: 0.0067 - val_mae: 0.0452
# Epoch 20/30
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0080 - mae: 0.0524 - val_loss: 0.0064 - val_mae: 0.0441
# Epoch 21/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0079 - mae: 0.0525 - val_loss: 0.0061 - val_mae: 0.0419
# Epoch 22/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0073 - mae: 0.0497 - val_loss: 0.0060 - val_mae: 0.0431
# Epoch 23/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0076 - mae: 0.0519 - val_loss: 0.0058 - val_mae: 0.0408
# Epoch 24/30
# 58/58 [==============================] - 2s 26ms/step - loss: 0.0078 - mae: 0.0530 - val_loss: 0.0058 - val_mae: 0.0415
# Epoch 25/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0072 - mae: 0.0502 - val_loss: 0.0060 - val_mae: 0.0462
# Epoch 26/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0069 - mae: 0.0496 - val_loss: 0.0055 - val_mae: 0.0433
# Epoch 27/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0068 - mae: 0.0505 - val_loss: 0.0063 - val_mae: 0.0507
# Epoch 28/30
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0063 - mae: 0.0475 - val_loss: 0.0060 - val_mae: 0.0496
# Epoch 29/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0064 - mae: 0.0480 - val_loss: 0.0073 - val_mae: 0.0588
# Epoch 30/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0064 - mae: 0.0499 - val_loss: 0.0051 - val_mae: 0.0427
# Epoch 1/30
# 58/58 [==============================] - 5s 26ms/step - loss: 0.0597 - mae: 0.1395 - val_loss: 0.0342 - val_mae: 0.0937
# Epoch 2/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0323 - mae: 0.0860 - val_loss: 0.0385 - val_mae: 0.1276
# Epoch 3/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0272 - mae: 0.0806 - val_loss: 0.0262 - val_mae: 0.0910
# Epoch 4/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0224 - mae: 0.0713 - val_loss: 0.0198 - val_mae: 0.0715
# Epoch 5/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0193 - mae: 0.0669 - val_loss: 0.0151 - val_mae: 0.0545
# Epoch 6/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0169 - mae: 0.0650 - val_loss: 0.0145 - val_mae: 0.0593
# Epoch 7/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0151 - mae: 0.0623 - val_loss: 0.0141 - val_mae: 0.0653
# Epoch 8/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0140 - mae: 0.0624 - val_loss: 0.0122 - val_mae: 0.0570
# Epoch 9/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0123 - mae: 0.0593 - val_loss: 0.0125 - val_mae: 0.0669
# Epoch 10/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0125 - mae: 0.0620 - val_loss: 0.0113 - val_mae: 0.0589
# Epoch 11/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0111 - mae: 0.0575 - val_loss: 0.0093 - val_mae: 0.0501
# Epoch 12/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0100 - mae: 0.0535 - val_loss: 0.0085 - val_mae: 0.0473
# Epoch 13/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0101 - mae: 0.0550 - val_loss: 0.0091 - val_mae: 0.0557
# Epoch 14/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0096 - mae: 0.0550 - val_loss: 0.0120 - val_mae: 0.0758
# Epoch 15/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0088 - mae: 0.0533 - val_loss: 0.0095 - val_mae: 0.0615
# Epoch 16/30
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0091 - mae: 0.0551 - val_loss: 0.0105 - val_mae: 0.0697
# Epoch 17/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0089 - mae: 0.0541 - val_loss: 0.0082 - val_mae: 0.0554
# Epoch 18/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0087 - mae: 0.0548 - val_loss: 0.0060 - val_mae: 0.0394
# Epoch 19/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0077 - mae: 0.0512 - val_loss: 0.0065 - val_mae: 0.0450
# Epoch 20/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0076 - mae: 0.0516 - val_loss: 0.0054 - val_mae: 0.0369
# Epoch 21/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0074 - mae: 0.0508 - val_loss: 0.0061 - val_mae: 0.0450
# Epoch 22/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0070 - mae: 0.0488 - val_loss: 0.0073 - val_mae: 0.0562
# Epoch 23/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0070 - mae: 0.0489 - val_loss: 0.0050 - val_mae: 0.0373
# Epoch 24/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0070 - mae: 0.0508 - val_loss: 0.0058 - val_mae: 0.0443
# Epoch 25/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0068 - mae: 0.0497 - val_loss: 0.0058 - val_mae: 0.0457
# Epoch 26/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0071 - mae: 0.0522 - val_loss: 0.0082 - val_mae: 0.0658
# Epoch 27/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0065 - mae: 0.0489 - val_loss: 0.0059 - val_mae: 0.0480
# Epoch 28/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0062 - mae: 0.0482 - val_loss: 0.0051 - val_mae: 0.0429
# Epoch 29/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0066 - mae: 0.0505 - val_loss: 0.0087 - val_mae: 0.0709
# Epoch 30/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0062 - mae: 0.0491 - val_loss: 0.0072 - val_mae: 0.0608
# Epoch 1/30
# 58/58 [==============================] - 3s 23ms/step - loss: 0.0619 - mae: 0.1455 - val_loss: 0.0243 - val_mae: 0.0356
# Epoch 2/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0329 - mae: 0.0878 - val_loss: 0.0200 - val_mae: 0.0267
# Epoch 3/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0269 - mae: 0.0766 - val_loss: 0.0170 - val_mae: 0.0295
# Epoch 4/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0229 - mae: 0.0718 - val_loss: 0.0142 - val_mae: 0.0275
# Epoch 5/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0195 - mae: 0.0686 - val_loss: 0.0132 - val_mae: 0.0382
# Epoch 6/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0173 - mae: 0.0662 - val_loss: 0.0109 - val_mae: 0.0306
# Epoch 7/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0161 - mae: 0.0660 - val_loss: 0.0094 - val_mae: 0.0255
# Epoch 8/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0144 - mae: 0.0629 - val_loss: 0.0084 - val_mae: 0.0238
# Epoch 9/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0137 - mae: 0.0629 - val_loss: 0.0080 - val_mae: 0.0279
# Epoch 10/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0116 - mae: 0.0565 - val_loss: 0.0070 - val_mae: 0.0224
# Epoch 11/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0116 - mae: 0.0584 - val_loss: 0.0067 - val_mae: 0.0242
# Epoch 12/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0115 - mae: 0.0598 - val_loss: 0.0062 - val_mae: 0.0209
# Epoch 13/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0102 - mae: 0.0534 - val_loss: 0.0060 - val_mae: 0.0227
# Epoch 14/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0103 - mae: 0.0562 - val_loss: 0.0079 - val_mae: 0.0476
# Epoch 15/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0098 - mae: 0.0554 - val_loss: 0.0063 - val_mae: 0.0351
# Epoch 16/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0097 - mae: 0.0559 - val_loss: 0.0058 - val_mae: 0.0283
# Epoch 17/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0099 - mae: 0.0596 - val_loss: 0.0052 - val_mae: 0.0265
# Epoch 18/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0087 - mae: 0.0529 - val_loss: 0.0051 - val_mae: 0.0273
# Epoch 19/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0086 - mae: 0.0533 - val_loss: 0.0052 - val_mae: 0.0299
# Epoch 20/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0087 - mae: 0.0556 - val_loss: 0.0055 - val_mae: 0.0351
# Epoch 21/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0082 - mae: 0.0528 - val_loss: 0.0048 - val_mae: 0.0285
# Epoch 22/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0079 - mae: 0.0521 - val_loss: 0.0042 - val_mae: 0.0227
# Epoch 23/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0075 - mae: 0.0495 - val_loss: 0.0046 - val_mae: 0.0284
# Epoch 24/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0072 - mae: 0.0494 - val_loss: 0.0041 - val_mae: 0.0243
# Epoch 25/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0070 - mae: 0.0486 - val_loss: 0.0040 - val_mae: 0.0241
# Epoch 26/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0069 - mae: 0.0493 - val_loss: 0.0037 - val_mae: 0.0221
# Epoch 27/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0073 - mae: 0.0522 - val_loss: 0.0041 - val_mae: 0.0290
# Epoch 28/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0071 - mae: 0.0508 - val_loss: 0.0039 - val_mae: 0.0256
# Epoch 29/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0067 - mae: 0.0490 - val_loss: 0.0050 - val_mae: 0.0415
# Epoch 30/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0066 - mae: 0.0491 - val_loss: 0.0036 - val_mae: 0.0254
# Epoch 1/30
# 58/58 [==============================] - 3s 20ms/step - loss: 0.0744 - mae: 0.1630 - val_loss: 0.0259 - val_mae: 0.0428
# Epoch 2/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0336 - mae: 0.0863 - val_loss: 0.0227 - val_mae: 0.0416
# Epoch 3/30
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0288 - mae: 0.0795 - val_loss: 0.0223 - val_mae: 0.0605
# Epoch 4/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0246 - mae: 0.0743 - val_loss: 0.0173 - val_mae: 0.0469
# Epoch 5/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0212 - mae: 0.0697 - val_loss: 0.0152 - val_mae: 0.0460
# Epoch 6/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0188 - mae: 0.0682 - val_loss: 0.0134 - val_mae: 0.0392
# Epoch 7/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0177 - mae: 0.0691 - val_loss: 0.0128 - val_mae: 0.0519
# Epoch 8/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0157 - mae: 0.0652 - val_loss: 0.0111 - val_mae: 0.0441
# Epoch 9/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0157 - mae: 0.0692 - val_loss: 0.0104 - val_mae: 0.0417
# Epoch 10/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0126 - mae: 0.0577 - val_loss: 0.0089 - val_mae: 0.0363
# Epoch 11/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0127 - mae: 0.0604 - val_loss: 0.0088 - val_mae: 0.0418
# Epoch 12/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0117 - mae: 0.0591 - val_loss: 0.0083 - val_mae: 0.0419
# Epoch 13/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0112 - mae: 0.0575 - val_loss: 0.0087 - val_mae: 0.0491
# Epoch 14/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0107 - mae: 0.0576 - val_loss: 0.0081 - val_mae: 0.0428
# Epoch 15/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0106 - mae: 0.0584 - val_loss: 0.0074 - val_mae: 0.0431
# Epoch 16/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0101 - mae: 0.0564 - val_loss: 0.0069 - val_mae: 0.0396
# Epoch 17/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0096 - mae: 0.0555 - val_loss: 0.0068 - val_mae: 0.0390
# Epoch 18/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0089 - mae: 0.0532 - val_loss: 0.0064 - val_mae: 0.0371
# Epoch 19/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0088 - mae: 0.0535 - val_loss: 0.0060 - val_mae: 0.0358
# Epoch 20/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0081 - mae: 0.0516 - val_loss: 0.0065 - val_mae: 0.0446
# Epoch 21/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0081 - mae: 0.0526 - val_loss: 0.0058 - val_mae: 0.0392
# Epoch 22/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0077 - mae: 0.0497 - val_loss: 0.0054 - val_mae: 0.0364
# Epoch 23/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0081 - mae: 0.0534 - val_loss: 0.0053 - val_mae: 0.0377
# Epoch 24/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0076 - mae: 0.0513 - val_loss: 0.0053 - val_mae: 0.0382
# Epoch 25/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0075 - mae: 0.0514 - val_loss: 0.0054 - val_mae: 0.0379
# Epoch 26/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0072 - mae: 0.0510 - val_loss: 0.0051 - val_mae: 0.0380
# Epoch 27/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0075 - mae: 0.0533 - val_loss: 0.0050 - val_mae: 0.0388
# Epoch 28/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0072 - mae: 0.0520 - val_loss: 0.0051 - val_mae: 0.0371
# Epoch 29/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0068 - mae: 0.0502 - val_loss: 0.0050 - val_mae: 0.0411
# Epoch 30/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0066 - mae: 0.0488 - val_loss: 0.0049 - val_mae: 0.0396
# Epoch 1/30
# 58/58 [==============================] - 3s 22ms/step - loss: 0.0533 - mae: 0.1317 - val_loss: 0.0248 - val_mae: 0.0405
# Epoch 2/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0342 - mae: 0.0910 - val_loss: 0.0209 - val_mae: 0.0391
# Epoch 3/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0277 - mae: 0.0814 - val_loss: 0.0181 - val_mae: 0.0439
# Epoch 4/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0216 - mae: 0.0704 - val_loss: 0.0153 - val_mae: 0.0436
# Epoch 5/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0194 - mae: 0.0689 - val_loss: 0.0137 - val_mae: 0.0485
# Epoch 6/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0161 - mae: 0.0635 - val_loss: 0.0110 - val_mae: 0.0378
# Epoch 7/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0148 - mae: 0.0630 - val_loss: 0.0098 - val_mae: 0.0372
# Epoch 8/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0137 - mae: 0.0625 - val_loss: 0.0097 - val_mae: 0.0455
# Epoch 9/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0128 - mae: 0.0633 - val_loss: 0.0082 - val_mae: 0.0383
# Epoch 10/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0116 - mae: 0.0594 - val_loss: 0.0077 - val_mae: 0.0393
# Epoch 11/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0108 - mae: 0.0590 - val_loss: 0.0078 - val_mae: 0.0448
# Epoch 12/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.0107 - mae: 0.0591 - val_loss: 0.0064 - val_mae: 0.0326
# Epoch 13/30
# 58/58 [==============================] - 2s 29ms/step - loss: 0.0092 - mae: 0.0532 - val_loss: 0.0061 - val_mae: 0.0346
# Epoch 14/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0090 - mae: 0.0541 - val_loss: 0.0056 - val_mae: 0.0317
# Epoch 15/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0085 - mae: 0.0531 - val_loss: 0.0058 - val_mae: 0.0369
# Epoch 16/30
# 58/58 [==============================] - 2s 27ms/step - loss: 0.0090 - mae: 0.0554 - val_loss: 0.0056 - val_mae: 0.0370
# Epoch 17/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0085 - mae: 0.0545 - val_loss: 0.0052 - val_mae: 0.0343
# Epoch 18/30
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0082 - mae: 0.0541 - val_loss: 0.0052 - val_mae: 0.0333
# Epoch 19/30
# 58/58 [==============================] - 1s 22ms/step - loss: 0.0082 - mae: 0.0552 - val_loss: 0.0047 - val_mae: 0.0304
# Epoch 20/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0075 - mae: 0.0518 - val_loss: 0.0046 - val_mae: 0.0318
# Epoch 21/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0076 - mae: 0.0526 - val_loss: 0.0049 - val_mae: 0.0349
# Epoch 22/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0068 - mae: 0.0496 - val_loss: 0.0042 - val_mae: 0.0309
# Epoch 23/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0070 - mae: 0.0507 - val_loss: 0.0040 - val_mae: 0.0290
# Epoch 24/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0072 - mae: 0.0527 - val_loss: 0.0046 - val_mae: 0.0354
# Epoch 25/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0067 - mae: 0.0491 - val_loss: 0.0045 - val_mae: 0.0364
# Epoch 26/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0066 - mae: 0.0505 - val_loss: 0.0048 - val_mae: 0.0401
# Epoch 27/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0069 - mae: 0.0532 - val_loss: 0.0039 - val_mae: 0.0323
# Epoch 28/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0063 - mae: 0.0498 - val_loss: 0.0041 - val_mae: 0.0330
# Epoch 29/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0058 - mae: 0.0471 - val_loss: 0.0034 - val_mae: 0.0292
# Epoch 30/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0060 - mae: 0.0490 - val_loss: 0.0038 - val_mae: 0.0340
# Epoch 1/30
# 58/58 [==============================] - 4s 26ms/step - loss: 0.0514 - mae: 0.1245 - val_loss: 0.0239 - val_mae: 0.0298
# Epoch 2/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0319 - mae: 0.0835 - val_loss: 0.0207 - val_mae: 0.0333
# Epoch 3/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0263 - mae: 0.0732 - val_loss: 0.0163 - val_mae: 0.0214
# Epoch 4/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0227 - mae: 0.0711 - val_loss: 0.0136 - val_mae: 0.0212
# Epoch 5/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0189 - mae: 0.0656 - val_loss: 0.0114 - val_mae: 0.0188
# Epoch 6/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0169 - mae: 0.0643 - val_loss: 0.0105 - val_mae: 0.0275
# Epoch 7/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0155 - mae: 0.0638 - val_loss: 0.0089 - val_mae: 0.0215
# Epoch 8/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0138 - mae: 0.0606 - val_loss: 0.0080 - val_mae: 0.0226
# Epoch 9/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0121 - mae: 0.0563 - val_loss: 0.0082 - val_mae: 0.0329
# Epoch 10/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0115 - mae: 0.0570 - val_loss: 0.0068 - val_mae: 0.0214
# Epoch 11/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0111 - mae: 0.0558 - val_loss: 0.0065 - val_mae: 0.0234
# Epoch 12/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0107 - mae: 0.0559 - val_loss: 0.0069 - val_mae: 0.0308
# Epoch 13/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0107 - mae: 0.0581 - val_loss: 0.0062 - val_mae: 0.0288
# Epoch 14/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0098 - mae: 0.0559 - val_loss: 0.0055 - val_mae: 0.0230
# Epoch 15/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0100 - mae: 0.0567 - val_loss: 0.0057 - val_mae: 0.0263
# Epoch 16/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0089 - mae: 0.0525 - val_loss: 0.0053 - val_mae: 0.0250
# Epoch 17/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0086 - mae: 0.0519 - val_loss: 0.0052 - val_mae: 0.0276
# Epoch 18/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0085 - mae: 0.0524 - val_loss: 0.0048 - val_mae: 0.0236
# Epoch 19/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0080 - mae: 0.0513 - val_loss: 0.0046 - val_mae: 0.0233
# Epoch 20/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0078 - mae: 0.0499 - val_loss: 0.0046 - val_mae: 0.0259
# Epoch 21/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0077 - mae: 0.0499 - val_loss: 0.0044 - val_mae: 0.0251
# Epoch 22/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0074 - mae: 0.0502 - val_loss: 0.0047 - val_mae: 0.0297
# Epoch 23/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0069 - mae: 0.0472 - val_loss: 0.0048 - val_mae: 0.0328
# Epoch 24/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0074 - mae: 0.0507 - val_loss: 0.0040 - val_mae: 0.0246
# Epoch 25/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0075 - mae: 0.0524 - val_loss: 0.0052 - val_mae: 0.0399
# Epoch 26/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0072 - mae: 0.0504 - val_loss: 0.0037 - val_mae: 0.0238
# Epoch 27/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0068 - mae: 0.0488 - val_loss: 0.0040 - val_mae: 0.0292
# Epoch 28/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0065 - mae: 0.0485 - val_loss: 0.0051 - val_mae: 0.0425
# Epoch 29/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0064 - mae: 0.0481 - val_loss: 0.0037 - val_mae: 0.0267
# Epoch 30/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0061 - mae: 0.0461 - val_loss: 0.0041 - val_mae: 0.0318
# Epoch 1/30
# 58/58 [==============================] - 3s 21ms/step - loss: 0.0603 - mae: 0.1373 - val_loss: 0.0321 - val_mae: 0.0875
# Epoch 2/30
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0335 - mae: 0.0889 - val_loss: 0.0233 - val_mae: 0.0567
# Epoch 3/30
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0266 - mae: 0.0755 - val_loss: 0.0220 - val_mae: 0.0680
# Epoch 4/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0229 - mae: 0.0726 - val_loss: 0.0168 - val_mae: 0.0510
# Epoch 5/30
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0196 - mae: 0.0699 - val_loss: 0.0138 - val_mae: 0.0448
# Epoch 6/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0181 - mae: 0.0683 - val_loss: 0.0127 - val_mae: 0.0494
# Epoch 7/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0159 - mae: 0.0654 - val_loss: 0.0122 - val_mae: 0.0545
# Epoch 8/30
# 58/58 [==============================] - 1s 14ms/step - loss: 0.0145 - mae: 0.0648 - val_loss: 0.0109 - val_mae: 0.0503
# Epoch 9/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0131 - mae: 0.0612 - val_loss: 0.0102 - val_mae: 0.0511
# Epoch 10/30
# 58/58 [==============================] - 1s 15ms/step - loss: 0.0121 - mae: 0.0601 - val_loss: 0.0089 - val_mae: 0.0437
# Epoch 11/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0116 - mae: 0.0592 - val_loss: 0.0083 - val_mae: 0.0439
# Epoch 12/30
# 58/58 [==============================] - 1s 23ms/step - loss: 0.0110 - mae: 0.0591 - val_loss: 0.0080 - val_mae: 0.0415
# Epoch 13/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0102 - mae: 0.0563 - val_loss: 0.0075 - val_mae: 0.0399
# Epoch 14/30
# 58/58 [==============================] - 1s 24ms/step - loss: 0.0098 - mae: 0.0558 - val_loss: 0.0072 - val_mae: 0.0429
# Epoch 15/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0092 - mae: 0.0542 - val_loss: 0.0079 - val_mae: 0.0510
# Epoch 16/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0091 - mae: 0.0542 - val_loss: 0.0076 - val_mae: 0.0514
# Epoch 17/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0088 - mae: 0.0548 - val_loss: 0.0064 - val_mae: 0.0405
# Epoch 18/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0086 - mae: 0.0540 - val_loss: 0.0076 - val_mae: 0.0536
# Epoch 19/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0085 - mae: 0.0537 - val_loss: 0.0118 - val_mae: 0.0799
# Epoch 20/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0079 - mae: 0.0514 - val_loss: 0.0080 - val_mae: 0.0577
# Epoch 21/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0080 - mae: 0.0539 - val_loss: 0.0057 - val_mae: 0.0394
# Epoch 22/30
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0075 - mae: 0.0515 - val_loss: 0.0068 - val_mae: 0.0516
# Epoch 23/30
# 58/58 [==============================] - 1s 21ms/step - loss: 0.0075 - mae: 0.0520 - val_loss: 0.0056 - val_mae: 0.0421
# Epoch 24/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0067 - mae: 0.0488 - val_loss: 0.0058 - val_mae: 0.0446
# Epoch 25/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0070 - mae: 0.0506 - val_loss: 0.0053 - val_mae: 0.0409
# Epoch 26/30
# 58/58 [==============================] - 1s 20ms/step - loss: 0.0070 - mae: 0.0513 - val_loss: 0.0058 - val_mae: 0.0474
# Epoch 27/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0070 - mae: 0.0521 - val_loss: 0.0057 - val_mae: 0.0461
# Epoch 28/30
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0065 - mae: 0.0487 - val_loss: 0.0054 - val_mae: 0.0450
# Epoch 29/30
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0062 - mae: 0.0486 - val_loss: 0.0056 - val_mae: 0.0468
# Epoch 30/30
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0060 - mae: 0.0473 - val_loss: 0.0049 - val_mae: 0.0418

# %%
# Plot Training and Validation Loss
plt.figure(figsize=(10, 6))
plt.plot(best_history.history['loss'], label='Training Loss')
plt.plot(best_history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Re-train the best model on the entire training dataset (excluding the final validation set)
best_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1, callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/30
#  1/52 [..............................] - ETA: 1s - loss: 0.0044 - mae: 0.0398
# 52/52 [==============================] - 1s 18ms/step - loss: 0.0059 - mae: 0.0480 - val_loss: 0.0074 - val_mae: 0.0627
# Epoch 2/30
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0060 - mae: 0.0498 - val_loss: 0.0055 - val_mae: 0.0505
# Epoch 3/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0052 - mae: 0.0443 - val_loss: 0.0046 - val_mae: 0.0428
# Epoch 4/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0056 - mae: 0.0469 - val_loss: 0.0064 - val_mae: 0.0570
# Epoch 5/30
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0059 - mae: 0.0494 - val_loss: 0.0056 - val_mae: 0.0516
# Epoch 6/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0059 - mae: 0.0499 - val_loss: 0.0045 - val_mae: 0.0407
# Epoch 7/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0052 - mae: 0.0451 - val_loss: 0.0048 - val_mae: 0.0447
# Epoch 8/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0050 - mae: 0.0448 - val_loss: 0.0044 - val_mae: 0.0418
# Epoch 9/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0048 - mae: 0.0442 - val_loss: 0.0046 - val_mae: 0.0455
# Epoch 10/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0055 - mae: 0.0477 - val_loss: 0.0064 - val_mae: 0.0559
# Epoch 11/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0052 - mae: 0.0466 - val_loss: 0.0043 - val_mae: 0.0419
# Epoch 12/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0051 - mae: 0.0464 - val_loss: 0.0047 - val_mae: 0.0458
# Epoch 13/30
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0051 - mae: 0.0469 - val_loss: 0.0045 - val_mae: 0.0448
# Epoch 14/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0050 - mae: 0.0464 - val_loss: 0.0042 - val_mae: 0.0425
# Epoch 15/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0049 - mae: 0.0458 - val_loss: 0.0045 - val_mae: 0.0450
# Epoch 16/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0051 - mae: 0.0471 - val_loss: 0.0038 - val_mae: 0.0387
# Epoch 17/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0049 - mae: 0.0462 - val_loss: 0.0073 - val_mae: 0.0655
# Epoch 18/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0051 - mae: 0.0477 - val_loss: 0.0046 - val_mae: 0.0471
# Epoch 19/30
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0049 - mae: 0.0466 - val_loss: 0.0058 - val_mae: 0.0545
# Epoch 20/30
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0051 - mae: 0.0479 - val_loss: 0.0055 - val_mae: 0.0546
# Epoch 21/30
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0044 - mae: 0.0428 - val_loss: 0.0049 - val_mae: 0.0500
# Epoch 22/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0043 - mae: 0.0423 - val_loss: 0.0062 - val_mae: 0.0584
# Epoch 23/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0048 - mae: 0.0470 - val_loss: 0.0073 - val_mae: 0.0661
# Epoch 24/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0050 - mae: 0.0478 - val_loss: 0.0047 - val_mae: 0.0476
# Epoch 25/30
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0046 - mae: 0.0457 - val_loss: 0.0046 - val_mae: 0.0489
# Epoch 26/30
# 52/52 [==============================] - 1s 18ms/step - loss: 0.0045 - mae: 0.0445 - val_loss: 0.0046 - val_mae: 0.0474

# %% [markdown]
# ## Testing

# %%
# Make predictions on the test data
test_predictions = best_model.predict(X_test)

# Inverse transform the predictions and actual values to their original scale
predictions = target_scaler.inverse_transform(test_predictions)
actual = target_scaler.inverse_transform(y_test)
# Out:
# 5/5 [==============================] - 1s 6ms/step

# %% [markdown]
# ## Score

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

# Calculate evaluation metrics
mse = mean_squared_error(actual, predictions)
mae = mean_absolute_error(actual, predictions)
rmse = np.sqrt(mse)

r2 = r2_score(actual, predictions)

# Adjusted R-squared
n = test_size  # Number of observations
p = len(features.columns)   # Number of predictors
adj_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

mape = mean_absolute_percentage_error(actual, predictions)

print("Mean Squared Error (MSE):", round(mse, 2))
print("Mean Absolute Error (MAE):", round(mae, 2))
print("Root Mean Squared Error (RMSE):", round(rmse, 2))
print("R-squared (R2):", round(r2, 2))
print("Adjusted R-squared:", round(adj_r2, 2))
print("Mean Absolute Percentage Error (MAPE):", round(mape, 2))
# Out:
# Mean Squared Error (MSE): 267.85
# Mean Absolute Error (MAE): 13.6
# Root Mean Squared Error (RMSE): 16.37
# R-squared (R2): 0.56
# Adjusted R-squared: 0.53
# Mean Absolute Percentage Error (MAPE): 0.06

# %% [markdown]
# ### Mean Squared Error (MSE) and Mean Absolute Error (MAE):
#
# - These metrics measure the average error between the predicted and actual values.
# - Lower values indicate better performance.
# - However, the absolute scale of these metrics is dependent on the scale of your target variable. Therefore, it's difficult to define a universally "good" threshold. It's more informative to compare these metrics across different models or variations of your LSTM model.
#
# ### Root Mean Squared Error (RMSE):
#
# - RMSE is in the same units as the target variable, which can make it more interpretable.
# - Similar to MSE and MAE, lower values are desirable.
# - Like MSE and MAE, it's more useful for comparing models rather than establishing absolute thresholds.
#
# ### R-squared (R2) and Adjusted R-squared:
#
# - R2 measures the proportion of the variance in the dependent variable that is predictable from the independent variables.
# - R2 ranges from 0 to 1, with higher values indicating better fit.
# - A value of 1 indicates that the model explains all the variability of the response data around its mean. However, a high R2 value doesn't necessarily mean a good model, as it may overfit.
# - Adjusted R-squared adjusts the R2 value based on the number of predictors in the model, providing a more accurate measure of model performance, especially with multiple variables.
# - Generally, R2 values closer to 1 and higher Adjusted R-squared values are desirable, but the interpretation depends on the context and the complexity of the model.
#
# ### Mean Absolute Percentage Error (MAPE):
#
# - MAPE measures the average absolute percentage difference between predicted and actual values.
# - Lower values indicate better performance.
# - A MAPE of 0% indicates a perfect fit, but in practice, it's rare to achieve such a value.
# - It's common to interpret MAPE in the context of the variability of the target variable. For example, a MAPE below 10% might be considered good in some domains.

# %% [markdown]
# ## Prediction

# %%
# Making future predictions
def predict_future(model, last_sequence, n_days):
    last_sequence = last_sequence.reshape((1, sequence_length, last_sequence.shape[1]))
    future_predictions = model.predict(last_sequence)[0]
    return future_predictions

# Use the last sequence from the dataset as input
last_sequence = X[-1]
future_predictions = predict_future(model, last_sequence, n_days)
# Out:
# 1/1 [==============================] - 0s 447ms/step

# %%
future_predictions = target_scaler.inverse_transform(future_predictions.reshape(-1, 1))
future_predictions
# Out:
# array([[211.03471],
#        [214.42664],
#        [213.34204],
#        [218.24738],
#        [221.87257]], dtype=float32)

# %%
import matplotlib.dates as mdates

# Function to generate future dates excluding weekends
def generate_future_weekdays(start_date, n_days):
    future_dates = []
    current_date = start_date
    while len(future_dates) < n_days:
        current_date += datetime.timedelta(days=1)
        # Check if current_date is a weekday (Monday=0, Sunday=6)
        if current_date.weekday() < 5:  # Weekdays are 0-4
            future_dates.append(current_date)
    return future_dates

# Historical data
historical_dates = data.index[-10:]  # Last 20 days from the historical data
historical_prices = data['Close'][-10:]

# Generate future weekday dates for predictions
last_date = datetime.datetime.strptime(str(historical_dates[-1]), '%Y-%m-%d')
future_weekday_dates = generate_future_weekdays(last_date, n_days)

# Plotting
plt.figure(figsize=(14, 7))
plt.plot(historical_dates, historical_prices, label='Historical Close Prices', marker='o')
plt.plot(future_weekday_dates, future_predictions, label='Predicted Future Close Prices', linestyle='--', marker='o', color='red')

plt.title(f'Predicted Future Close Prices ({ticker})')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.xticks(rotation=45)

plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gcf().autofmt_xdate()

plt.show()

# %% [markdown]
# Here's the refactored explanation to match your updated code:
#
# ## Future Price Prediction Explanation
#
# The future price prediction in this model leverages a function that iteratively forecasts prices for a specified number of days ahead, utilizing the most recent input data. This approach is particularly pertinent for predicting stock prices where future values (like the next day's 'Open', 'High', 'Low') are unknown.
#
# ### Preparing the Last Known Input
#
# The prediction process commences with the preparation of the last known input data, which is the most recent data point available from the dataset. This last input is crucial as it serves as the starting point for future predictions. The code snippet for this preparation is:
#
# ```python
# last_known_input = scaled_features_df.iloc[-1:].values  # Use the last known input features
# ```
#
# Here, `scaled_features_df.iloc[-1:]` fetches the last row of the scaled feature dataset, representing the most recent day's data.
#
# ### Iterative Future Prediction
#
# The essence of the future price prediction lies in an iterative mechanism where each prediction is subsequently used as input for the next. This iterative forecasting is encapsulated in the `predict_future_days` function:
#
# ```python
# def predict_future_days(model, last_input, feature_scaler, target_scaler, n_days):
#     future_predictions_scaled = []
#     input_sequence = last_input.copy()  # Copy the last known input sequence
#
#     for _ in range(n_days):
#         reshaped_input = input_sequence.reshape((1, 1, input_sequence.shape[1]))
#         next_day_prediction_scaled = model.predict(reshaped_input)
#         future_predictions_scaled.append(next_day_prediction_scaled[0, 0])
#         next_input_sequence = np.append(input_sequence[:, 1:], next_day_prediction_scaled, axis=1)
#         input_sequence = next_input_sequence
#
#     future_predictions_scaled = np.array(future_predictions_scaled).reshape(-1, 1)
#     future_predictions = target_scaler.inverse_transform(future_predictions_scaled)[:, 0]
#
#     return future_predictions
# ```
#
# In this function:
#
# - `input_sequence` starts as the last known input, and with each iteration, the model predicts the next day's price.
# - The prediction (`next_day_prediction_scaled`) is appended to `future_predictions_scaled`, accumulating the future price predictions.
# - `input_sequence` is updated with the new prediction, effectively simulating the input for the next day's prediction.
# - After completing the predictions for the desired number of days, the `future_predictions` are inversely transformed to the original price scale using the `target_scaler`.
#
# ### Conclusion
#
# This iterative prediction method allows for forecasting future stock prices based on historical data patterns. However, it's crucial to recognize that the accuracy of these predictions may diminish over time due to the cumulative effect of prediction errors and the absence of actual future inputs. This strategy presupposes that historical trends will persist, which may not always be the case in the volatile stock market environment.
